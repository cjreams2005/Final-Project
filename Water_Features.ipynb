# %% [markdown]
# # Introduction
# The objective of this project is to find the best neighborhood in Pittsburgh. We decided that to find it we would use metrics related to the best place to take a walk. I decided as my metric I would see which neighborhood has the most water features. When I'm taking walks I love seeing water features. There aesthetically pleasing and drinking fountains are great for walks when it hot out.

# %%
import pandas as pd
water_features = pd.read_csv("water_features.csv", index_col="_id")
water_features.head(5)
# Out:
#              id              name control_type       feature_type inactive  \
# _id
# 151  1228146070  Schenley Plaza 2       On/Off  Drinking Fountain        f
# 186   717679113                 3       On/Off         Decorative      NaN
# 152   993771927  Schenley Plaza 3       On/Off  Drinking Fountain        f
# 47    915807211       Fowler Park       On/Off  Drinking Fountain        f
# 183  1535919927    Woods Run Park       On/Off  Drinking Fountain        f
#
#                 make                                              image  \
# _id
# 151             Haws  https://tools.wprdc.org/images/pittsburgh/wate...
# 186             Haws  https://tools.wprdc.org/images/pittsburgh/wate...
# 152             Haws  https://tools.wprdc.org/images/pittsburgh/wate...
# 47   Most Dependable  https://tools.wprdc.org/images/pittsburgh/wate...
# 183  Most Dependable  https://tools.wprdc.org/images/pittsburgh/wate...
#
#            neighborhood  council_district  ward        tract  \
# _id
# 151       North Oakland                 8     4  42003982200
# 186    Brighton Heights                 1    27  42003270100
# 152       North Oakland                 8     4  42003982200
# 47          Perry South                 6    26  42003261400
# 183  Marshall-Shadeland                 1    27  42003271500
#
#      public_works_division  pli_division  police_zone fire_zone   latitude  \
# _id
# 151                      3             4            4       2-7  40.443063
# 186                      1            27            1      1-14  40.484408
# 152                      3             4            4       2-7  40.443217
# 47                       1            26            1      1-23  40.470420
# 183                      1            27            1      1-14  40.476287
#
#      longitude
# _id
# 151 -79.952901
# 186 -80.042337
# 152 -79.952299
# 47  -80.010933
# 183 -80.029336

# %%
count = water_features['neighborhood'].value_counts().rename_axis('neighborhood').reset_index(name='count')
print(count.head(15))
sorted = count.sort_values(by='count', ascending=False)
# Out:
#              neighborhood  count
# 0     Squirrel Hill South     14
# 1           Highland Park     12
# 2         Terrace Village      8
# 3              Bloomfield      8
# 4        Allegheny Center      8
# 5               Brookline      8
# 6             Perry North      7
# 7            Point Breeze      7
# 8        Mount Washington      6
# 9                 Carrick      6
# 10                Elliott      6
# 11           East Liberty      6
# 12       Brighton Heights      6
# 13              Troy Hill      6
# 14  Spring Hill-City View      6

# %%
import matplotlib.pyplot as plt
ft = pd.DataFrame(count).head(15)
ft.plot(x='neighborhood', y='count', kind='bar')
plt.title('Water Features in Pittsburgh Neighborhoods')
plt.xlabel('Neighborhoods')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# South Squirrel Hill is the neighborhood with the most water features. This isn't very surprising, since Squirrel hill is one of the more popular neighborhoods in Pittsburgh. Highland Park isn't too far behind, with 12, but then it drops off with a large number of neighborhoods having between 6-8 water features.
