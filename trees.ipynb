# %% [markdown]
# # Trees
# ### by Carly Bowen
# # Introduction
#
# In this notebook, the trails in Pittsburgh neighborhoods is evaluated. I cleaned up the dataset so I have key information needed for our metric. We were aiming to find the best neighborhood to have a nice and relaxing walk when you're in that kind of mood for a reset and refresh.

# %%
# load pandas
import pandas as pd
import numpy as np

# load data
tree_data = pd.read_csv("trees.csv", index_col="_id")

tree_data.head(5)
# Out:
# C:\Users\Carly\AppData\Local\Temp\ipykernel_9376\463844154.py:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   tree_data = pd.read_csv("trees.csv", index_col="_id")
#              id address_number         street         common_name  \
# _id
# 1     754166088         7428.0  MONTICELLO ST               Stump
# 2    1946899269          220.0     BALVER AVE  Linden: Littleleaf
# 3    1431517397         2822.0      SIDNEY ST          Maple: Red
# 4     994063598          608.0     SUISMON ST      Maple: Freeman
# 5    1591838573         1135.0   N NEGLEY AVE       Maple: Norway
#
#       scientific_name  height  width  growth_space_length  growth_space_width  \
# _id
# 1               Stump     0.0    0.0                 10.0                 2.0
# 2       Tilia cordata     0.0    0.0                 99.0                99.0
# 3         Acer rubrum    22.0    6.0                  6.0                 3.0
# 4    Acer x freemanii    25.0   10.0                  3.0                 3.0
# 5    Acer platanoides    52.0   13.0                 99.0                99.0
#
#         growth_space_type  diameter_base_height  stems condition  \
# _id
# 1             Well or Pit                  16.0    1.0       NaN
# 2    Open or Unrestricted                  22.0    0.0       NaN
# 3             Well or Pit                   6.0    1.0      Fair
# 4             Well or Pit                   7.0    1.0      Fair
# 5    Open or Unrestricted                  38.0    1.0      Good
#
#      overall_benefits_dollar_value      neighborhood   latitude  longitude
# _id
# 1                              NaN    Homewood North  40.458169 -79.889724
# 2                       125.178322           Oakwood  40.429269 -80.067868
# 3                        77.767116  South Side Flats  40.426797 -79.965035
# 4                        81.838259    East Allegheny  40.455503 -79.999276
# 5                       390.538994     Highland Park  40.476667 -79.924106

# %%
import pandas as pd

## makes new dataframe of how many trees are in each nieghborhood
tally = tree_data['neighborhood'].value_counts().rename_axis('Tree').reset_index(name='counts')

tally.head(10)
# Out:
#                         Tree  counts
# 0        Squirrel Hill South    5073
# 1              Highland Park    2941
# 2        Squirrel Hill North    2083
# 3           South Side Flats    1693
# 4                  Shadyside    1558
# 5                 Bloomfield    1436
# 6               East Liberty    1366
# 7               Point Breeze    1316
# 8                Perry North    1007
# 9  Central Business District    1002

# %%
## display bar chart of data so its easier to see

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(tally).head(10)

df.plot(x='Tree', y='counts', kind='bar')
plt.title('Trees in Pittsburgh Neighborhoods')
plt.xlabel('Neighborhood')
plt.ylabel('trees')
plt.show()

# %% [markdown]
# From the amount of trees point of view, Squirrel Hill South seems to have the most trees throughout the neighborhoods of Pittsburgh. Having a the most trees helps with cleaner air and a calmer environment. Thus, as for the trees metric, Squirrel Hill South beats out the rest of the other Pittsburgh neighborhoods. If our other metrics do not align with Squirrel Hill South, then the bar chart provides the top 10 neighborhoods with the most trees.
